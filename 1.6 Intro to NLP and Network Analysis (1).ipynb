# %% [markdown]
# # 1.6 Intro to NLP and Network Analysis

# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module

# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 12.8/12.8 MB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from en-core-web-sm==3.4.1) (3.4.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.3)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.23.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: setuptools in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (65.6.3)
# Requirement already satisfied: jinja2 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.6.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.9.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.7)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\owner\appdata\roaming\python\python310\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (21.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.6)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.12)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: colorama in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.5)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\owner\anaconda3\envs\venv_lotr\lib\site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Load Alice in Wonderland book

# %%
# Load the book

with open('alice_in_wonderland.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %%
book = NER(data)

# %%
# Visualize identified entities

displacy.render(book[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">, or a watch totake out of it, and burning with curiosity, she ran across thefield after it, and fortunately was just in time to see it popdown a large rabbit-hole under the hedge.  In another moment down went
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  after it, never onceconsidering how in the world she was to get out again.  The rabbit-hole went straight on like a tunnel for some way,and then dipped suddenly down, so suddenly that
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had not amoment to think about stopping herself before she found herselffalling down a very deep well.  Either the well was very deep, or she fell very slowly, for shehad plenty of time as she went down to look about her and towonder what was going to happen next.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# , she tried to lookdown and make out what she was coming to, but it was too dark tosee anything; then she looked at the sides of the well, andnoticed that they were filled with cupboards and book-shelves;here and there she saw maps and pictures hung upon pegs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shetook
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  down a jar from
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of the shelves as she passed; it waslabelled `ORANGE MARMALADE', but to her great disappointment itwas empty:  she did not like to drop the jar for fear of killingsomebody, so managed to put it into one of the cupboards as shefell past it.  `Well!' thought
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to herself, `after such a fall as this,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ishall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  think nothing of tumbling down stairs!  How brave they'llall think me at home!  Why, I wouldn't say anything about it,even if I fell off the top of the house!' (Which was very likelytrue.)
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Down
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , down, down.  Would the fall
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NEVER
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  come to an end!  `Iwonder how many miles I've fallen by this time?' she said aloud.`I must be getting somewhere near the centre of the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# .  Letme see:  that would be
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     four thousand miles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
#  down, I think--' (for,you see,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had learnt several things of this sort in herlessons in the schoolroom, and though this was not a VERY goodopportunity for showing off her knowledge, as there was no one tolisten to her, still it was good practice to say it over) `--yes,that's about the right distance--but then I wonder what
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Latitudeor Longitude
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  I've got to?'  (
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Alice
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had no idea what
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Latitude
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was,or
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Longitude
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  either, but thought they were nice grand words tosay.)  Presently she began again.  `I wonder if I shall fall rightTHROUGH the earth!  How funny it'll seem to come out among thepeople that walk with their heads downward!  The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Antipathies
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Ithink--' (she was rather glad there WAS no one listening, thistime, as it didn't sound at all the right word) `--but I shallhave to ask them what the name of the country is, you know.Please,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ma'am
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , is this
# <mark cla

# %% [markdown]
# ## Get named entity list per sentence

# %%
df_sentences = [] # empty shell to store results

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})
    
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (Alice, 's, Adventures, in, Wonderland,       ...
# 1  (I,                      , Down, the, Rabbit, ...
# 2  (So, she, was, considering, in, her, own, mind...
# 3  (There, was, nothing, so, VERY, remarkable, in...
# 4                                   (Oh, dear, !,  )
# 5                      (I, shall, be, late, !, ',  )
# 6  ((, when, she, thoughtit, over, afterwards, ,,...
# 7  (In, another, moment, down, went, Alice, after...
# 8  (The, rabbit, -, hole, went, straight, on, lik...
# 9  (Either, the, well, was, very, deep, ,, or, sh...
#
#                                             entities
# 0  [Alice, Adventures, Lewis Carroll             ...
# 1                                     [Alice, Alice]
# 2                                      [WhiteRabbit]
# 3                                           [Rabbit]
# 4                                                 []
# 5                                                 []
# 6                                            [Alice]
# 7                                            [Alice]
# 8                                            [Alice]
# 9                                                 []

# %% [markdown]
# ## Load character names

# %%
# Import characters

character_df = pd.read_csv("characters_alice.csv", index_col = 0)

# %%
character_df.head()
# Out:
#           character character_alias
# 0             Alice           Alice
# 1  The White Rabbit          Rabbit
# 2         The Mouse           Mouse
# 3          The Dodo            Dodo
# 4          The Lory            Lory

# %% [markdown]
# ## Filtering entities from the book

# %%
# Function to filter out entities not of interest

def filter_entity(ent_list, character_df):
    return [ent for ent in ent_list 
            if ent in list(character_df['character_alias'])]

# %%
# Check

filter_entity(["Alice", "CF", "2"], character_df)
# Out:
# ['Alice']

# %%
df_sentences['character_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, character_df))

# %%
df_sentences['character_entities'].head(20)
# Out:
# 0            [Alice]
# 1     [Alice, Alice]
# 2                 []
# 3           [Rabbit]
# 4                 []
# 5                 []
# 6            [Alice]
# 7            [Alice]
# 8            [Alice]
# 9                 []
# 10                []
# 11                []
# 12           [Alice]
# 13                []
# 14                []
# 15                []
# 16                []
# 17                []
# 18                []
# 19                []
# Name: character_entities, dtype: object

# %%
# Filter out sentences that don't have any character entities

df_sentences_filtered = df_sentences[df_sentences['character_entities'].map(len) > 0]

# %%
df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 1483  (`, The, idea, of, havingthe, sentence, first,...
# 1484           (`, I, wo, n't, !, ', said, Alice, .,  )
# 1486  (the, Queen, shouted, at, the, top, of, her, v...
# 1488  (`, Who, cares, for, you, ?, ', said, Alice, ,...
# 1491                (`, Wake, up, ,, Alice, dear, !, ')
# 1493  (`, Oh, ,, I, 've, had, such, a, curious, drea...
# 1494  (So, Alice, got, up, and, ran, off, ,, thinkin...
# 1495  (But, her, sister, sat, still, just, as, she, ...
# 1496  (The, long, grass, rustled, at, her, feet, as,...
# 1497  (So, she, sat, on, ,, with, closed, eyes, ,, a...
#
#                                entities       character_entities
# 1483                     [first, Queen]                  [Queen]
# 1484                            [Alice]                  [Alice]
# 1486                            [Queen]                  [Queen]
# 1488                            [Alice]                  [Alice]
# 1491                            [Alice]                  [Alice]
# 1493                            [Alice]                  [Alice]
# 1494                            [Alice]                  [Alice]
# 1495  [Alice, Adventures, First, Alice]           [Alice, Alice]
# 1496     [Mouse, March, Queen, Gryphon]  [Mouse, Queen, Gryphon]
# 1497             [half, Queen, Gryphon]         [Queen, Gryphon]

# %% [markdown]
# ## Create relationships

# %%
# Defining relationships 

# window size = 5 : this defines how many sentences will be looked at simultaneously 
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    char_list = sum((df_sentences_filtered.loc[i: end_i].character_entities), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#        source   target
# 0       Alice   Rabbit
# 1       Alice   Rabbit
# 2      Rabbit    Alice
# 3      Rabbit    Alice
# 4      Rabbit    Alice
# ...       ...      ...
# 1896    Queen  Gryphon
# 1897    Mouse    Queen
# 1898    Queen  Gryphon
# 1899  Gryphon    Queen
# 1900    Queen  Gryphon
#
# [1901 rows x 2 columns]

# %%
# Sort the cases with a->b and b->a

relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head(5)
# Out:
#   source  target
# 0  Alice  Rabbit
# 1  Alice  Rabbit
# 2  Alice  Rabbit
# 3  Alice  Rabbit
# 4  Alice  Rabbit

# %%
# Summarize the interactions

relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

# %%
relationship_df.head(10)
# Out:
#    source   target  value
# 0   Alice   Rabbit     90
# 1   Alice  Duchess    229
# 2   Alice    Mouse    110
# 3    Dodo    Mouse     10
# 4    Dodo     Lory      6
# 5  Eaglet     Lory      6
# 6   Alice   Eaglet      5
# 7   Alice     Lory     28
# 8    Lory    Mouse     29
# 9    Duck    Mouse      9

# %%
relationship_df.to_csv('alice_relationship.csv')
